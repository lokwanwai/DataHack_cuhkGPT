# %%
import pandas as pd
from pykml import parser
import folium

# Open KML file and parse its contents
with open('../data/raw/Metro System (MTR & KCR) in Hong Kong.kml') as f:
    doc = parser.parse(f)

# Extract data from KML file and store in a list of dictionaries
data = []
for pm in doc.getroot().Document.Folder.Placemark:
    d = {}
    d['name'] = pm.name.text.strip() if pm.name else ''
    d['description'] = pm.description.text.strip() if pm.description else ''
    try:
        coords = pm.Point.coordinates.text.strip().split(',')
        d['longitude'] = float(coords[0])
        d['latitude'] = float(coords[1])
        d['altitude'] = float(coords[2])
    except:
        pass
    data.append(d)

# Create DataFrame from list of dictionaries
gdf = pd.DataFrame(data)
gdf
# Out:
#                 name                                        description  \
# 0    Airport Express  <img src="https://lh3.googleusercontent.com/um...
# 1    Asia World-Expo  <img src="https://lh3.googleusercontent.com/um...
# 2      Airport (HKG)  <img src="https://lh3.googleusercontent.com/um...
# 3           Tsing Yi  <img src="https://lh3.googleusercontent.com/um...
# 4            Kowloon  <img src="https://lh3.googleusercontent.com/um...
# ..               ...                                                ...
# 103    Tai Shui Hang  <img src="https://lh3.googleusercontent.com/um...
# 104         Shek Mun  <img src="https://lh3.googleusercontent.com/um...
# 105         City One  <img src="https://lh3.googleusercontent.com/um...
# 106      Sha Tin Wai  <img src="https://lh3.googleusercontent.com/um...
# 107  Che Kung Temple  <img src="https://lh3.googleusercontent.com/um...
#
#       longitude   latitude  altitude
# 0           NaN        NaN       NaN
# 1    113.942304  22.321828       0.0
# 2    113.936548  22.315947       0.0
# 3    114.107459  22.358321       0.0
# 4    114.161500  22.304701       0.0
# ..          ...        ...       ...
# 103  114.222622  22.408241       0.0
# 104  114.208653  22.387887       0.0
# 105  114.203535  22.382956       0.0
# 106  114.194770  22.376944       0.0
# 107  114.186262  22.375049       0.0
#
# [108 rows x 5 columns]

# %%
gdf.dropna(inplace=True)
gdf
# Out:
#                 name                                        description  \
# 1    Asia World-Expo  <img src="https://lh3.googleusercontent.com/um...
# 2      Airport (HKG)  <img src="https://lh3.googleusercontent.com/um...
# 3           Tsing Yi  <img src="https://lh3.googleusercontent.com/um...
# 4            Kowloon  <img src="https://lh3.googleusercontent.com/um...
# 5          Hong Kong  <img src="https://lh3.googleusercontent.com/um...
# ..               ...                                                ...
# 103    Tai Shui Hang  <img src="https://lh3.googleusercontent.com/um...
# 104         Shek Mun  <img src="https://lh3.googleusercontent.com/um...
# 105         City One  <img src="https://lh3.googleusercontent.com/um...
# 106      Sha Tin Wai  <img src="https://lh3.googleusercontent.com/um...
# 107  Che Kung Temple  <img src="https://lh3.googleusercontent.com/um...
#
#       longitude   latitude  altitude
# 1    113.942304  22.321828       0.0
# 2    113.936548  22.315947       0.0
# 3    114.107459  22.358321       0.0
# 4    114.161500  22.304701       0.0
# 5    114.158179  22.284872       0.0
# ..          ...        ...       ...
# 103  114.222622  22.408241       0.0
# 104  114.208653  22.387887       0.0
# 105  114.203535  22.382956       0.0
# 106  114.194770  22.376944       0.0
# 107  114.186262  22.375049       0.0
#
# [98 rows x 5 columns]

# %%
gdf.to_csv("../data/processed/mtr.csv", index=False)

# %%
# create a map centered at Hong Kong
m = folium.Map(location=[22.3193, 114.1694], zoom_start=11)

# iterate through the rows of the dataframe and add markers to the map
for index, row in gdf.iterrows():
    name = row['name']
    lat = row['latitude']
    lon = row['longitude']
    popup = folium.Popup(name)
    marker = folium.Marker(location=[lat, lon], popup=popup)
    marker.add_to(m)

# display the map
m.save("../data/processed/mrtMap.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e71a4079fa31ae3faa2c996859839fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e71a4079fa31ae3faa2c996859839fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8e71a4079fa31ae3faa2c996859839fa = L.map(
#                 &quot;map_8e71a4079fa31ae3faa2c996859839fa&quot;,
#                 {
#                     center: [22.3193, 114.1694],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a52d47503d32422c502f967fec08ca5c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8e71a4079fa31ae3faa2c996859839fa);
#
#
#             var marker_2897916a293ab233f68d4a948ab55090 = L.marker(
#                 [22.321828, 113.942304],
#                 {}
#             ).addTo(map_8e71a4079fa31ae3faa2c996859839fa);
#
#
#         var popup_7a416a3f70b33e768daf2a02a3012ac3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fdcf11d369b8f45f0f0e8fda6addc8d2 = $(`&lt;div id=&quot;html_fdcf11d369b8f45f0f0e8fda6addc8d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Asia World-Expo&lt;/div&gt;`)[0];
#                 popup_7a416a3f70b33e768daf2a02a3012ac3.setContent(html_fdcf11d369b8f45f0f0e8fda6addc8d2);
#
#
#
#         marker_2897916a293ab233f68d4a948ab55090.bindPopup(popup_7a416a3f70b33e768daf2a02a3012ac3)
#         ;
#
#
#
#
#             var marker_6cd283443be4705486b47cf6090f47b1 = L.marker(
#                 [22.315947, 113.936548],
#                 {}
#             ).addTo(map_8e71a4079fa31ae3faa2c996859839fa);
#
#
#         var popup_8cfb5158f0e449c6a3e4e0b25b39cb77 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_76ae3bf47abdc614a0d1f5022f5d1c7a = $(`&lt;div id=&quot;html_76ae3bf47abdc614a0d1f5022f5d1c7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Airport (HKG)&lt;/div&gt;`)[0];
#                 popup_8cfb5158f0e449c6a3e4e0b25b39cb77.setContent(html_76ae3bf47abdc614a0d1f5022f5d1c7a);
#
#
#
#         marker_6cd283443be4705486b47cf6090f47b1.bindPopup(popup_8cfb5158f0e449c6a3e4e0b25b39cb77)
#         ;
#
#
#
#
#             var marker_41a2ac07bfa79747b3350e2c816b371a = L.marker(
#                 [22.358321, 114.107459],
#                 {}
#             ).addTo(map_8e71a4079fa31ae3faa2c996859839fa);
#
#
#         var popup_2fc377c0f9ff1b245ea9530410ed2756 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d23c98001ec3b950f495fb586c4d913 = $(`&lt;div id=&quot;html_9d23c98001ec3b950f495fb586c4d913&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tsing Yi&lt;/div&gt;`)[0];
#                 popup_2fc377c0f9ff1b245ea9530410ed2756.setContent(html_9d23c98001ec3b950f495fb586c4d913);
#
#
#
#         marker_41a2ac07bfa79747b3350e2c816b371a.bindPopup(popup_2fc377c0f9ff1b245ea9530410ed2756)
#         ;
#
#
#
#
#             var marker_a287ae012e786e3f307cc81b3a6c4708 = L.marker(
#                 [22.304701, 114.1615],
#                 {}
#             ).addTo(map_8e71a4079fa31ae3faa2c996859839fa);
#
#
#         var popup_8f85e22bfd0d0f2a47fee71a1cee2af5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_16fe67032994ba779095364261434aea = $(`&lt;div id=&quot;html_16fe67032994ba779095364261434aea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kowloon&lt;/div&gt;`)[0];
#                 popup_8f85e22bfd0d0f2a47fee71a1cee2af5.setContent(html_16fe67032994ba779095364261434aea);
#
#
#
#         marker_a287ae012e786e3f307cc81b3a6c4708.bindPopup(popup_8f85e22bfd0d0f2a47fee71a1cee2af5)
#         ;
#
#
#
#
#             var marker_28e379f7686c7af929daf2fc8a7ab310 = L.marker(
#                 [22.284872, 114.158179],
#                 {}
#             ).addTo(map_8e71a4079fa31ae3faa2c996859839fa);
#
#
#         var popup_9aedb88cc5a2ae42a15afa570271ca94 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c6ad33d09f6d4c6e59d204e8d030f4ac = $(`&lt;div id=&quot;html_c6ad33d09f6d4c6e59d204e8d030f4ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hong Kong&lt;/div&gt;`)[0];
#                 popup_9aedb88cc5a2ae42a15afa570271ca94.setContent(html_c6ad33d09f6d4c6e59d204e8d030f4ac);
#
#
#
#         marker_28e379f7686c7af929daf2fc8a7ab310.bindPopup(popup_9aedb88cc5a2ae42a15afa570271ca94)
#         ;
#
#
#
#
#             var marker_38e653286e6f57eca2a2ec61c7352011 = L.marker(
#                 [22.289007, 113.941537],
#                 {}
