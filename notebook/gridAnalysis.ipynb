# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_wellcome = pd.read_csv("../data/processed/wellcomeAnalysis.csv")
df_wellcome.head()
# Out:
#        name                                  formatted_address  \
# 0  Wellcome    84-90號 Queen's Road Central, Central, Hong Kong
# 1  wellcome  125, Metro Harbour View Plaza, 8 Fuk Lee St, T...
# 2  Wellcome                   319 Nathan Rd, Jordan, Hong Kong
# 3  Wellcome  Shop No.23, G/F, Hoi Fu Shopping Centre, 2 Hoi...
# 4  Wellcome  G/F, TG Place, 8 Shing Yip St, Kwun Tong, Hong...
#
#                       place_id  rating  user_ratings_total  \
# 0  ChIJ5b0oWHsABDQRJUwc57avQ94     3.8                 362
# 1  ChIJfzdi4rAABDQRYsiJViBAKIs     3.7                 259
# 2  ChIJG3W4guwABDQRsYiKQEyeUvU     3.6                 275
# 3  ChIJvdn9MLkABDQRbEofjcY9gsc     3.6                 215
# 4  ChIJabudQ0UBBDQRF2ggpcEzLiE     3.5                 182
#
#                                                types   latitude   longitude  \
# 0  ['supermarket', 'grocery_or_supermarket', 'sto...  22.283245  114.155105
# 1  ['supermarket', 'grocery_or_supermarket', 'sto...  22.324410  114.160454
# 2  ['supermarket', 'grocery_or_supermarket', 'sto...  22.306436  114.171362
# 3  ['supermarket', 'grocery_or_supermarket', 'sto...  22.315173  114.164415
# 4  ['supermarket', 'grocery_or_supermarket', 'sto...  22.310417  114.225745
#
#    num_bus_stops_within_1km  num_mtr_station_within_1km  \
# 0                       116                           5
# 1                       117                           6
# 2                        98                           3
# 3                        94                           5
# 4                        78                           3
#
#    num_competitor_within_1km                      district
# 0                          4  Central and Western District
# 1                         14                  Sham Shui Po
# 2                         13                 Yau Tsim Mong
# 3                         15                 Yau Tsim Mong
# 4                          4                     Kwon Tong

# %%
df_busStop = pd.read_csv("../data/processed/busStop.csv")
df_busStop
# Out:
#                           id  STOP_ID       X       Y LAST_UPDATE_DATE_STR  \
# 0       GS_BUS_STOP_VIEW.134      134  836298  815477           10/24/2022
# 1       GS_BUS_STOP_VIEW.135      135  836643  815593           10/24/2022
# 2       GS_BUS_STOP_VIEW.136      136  837048  815708           10/24/2022
# 3       GS_BUS_STOP_VIEW.137      137  837583  815779           10/24/2022
# 4       GS_BUS_STOP_VIEW.139      139  837920  816521           10/24/2022
# ...                      ...      ...     ...     ...                  ...
# 4331  GS_BUS_STOP_VIEW.12481    12481  835615  817421           10/24/2022
# 4332  GS_BUS_STOP_VIEW.12485    12485  842968  815028           10/24/2022
# 4333  GS_BUS_STOP_VIEW.12490    12490  831221  815835           10/24/2022
# 4334  GS_BUS_STOP_VIEW.12492    12492  843358  811767           10/24/2022
# 4335  GS_BUS_STOP_VIEW.12493    12493  839190  816946           10/24/2022
#
#                                            geometry   longitude   latitude
# 0     POINT (114.17716544074156 22.278157267915223)  114.177165  22.278157
# 1     POINT (114.18051304472341 22.279204780631602)  114.180513  22.279205
# 2      POINT (114.1844428939664 22.280243167292028)  114.184443  22.280243
# 3      POINT (114.1896341986785 22.280884016074378)  114.189634  22.280884
# 4     POINT (114.19290497970104 22.287584455024394)  114.192905  22.287584
# ...                                             ...         ...        ...
# 4331    POINT (114.1705374241285 22.29571269194325)  114.170537  22.295713
# 4332    POINT (114.241883363216 22.274089479539633)  114.241883  22.274089
# 4333   POINT (114.12790158128861 22.28138286518113)  114.127902  22.281383
# 4334   POINT (114.24565306959613 22.24463895455148)  114.245653  22.244639
# 4335  POINT (114.20522954326367 22.291420782958816)  114.205230  22.291421
#
# [4336 rows x 8 columns]

# %%
df_mtr = pd.read_csv("../data/processed/mtr.csv")
df_mtr
# Out:
#                name                                        description  \
# 0   Asia World-Expo  <img src="https://lh3.googleusercontent.com/um...
# 1     Airport (HKG)  <img src="https://lh3.googleusercontent.com/um...
# 2          Tsing Yi  <img src="https://lh3.googleusercontent.com/um...
# 3           Kowloon  <img src="https://lh3.googleusercontent.com/um...
# 4         Hong Kong  <img src="https://lh3.googleusercontent.com/um...
# ..              ...                                                ...
# 93    Tai Shui Hang  <img src="https://lh3.googleusercontent.com/um...
# 94         Shek Mun  <img src="https://lh3.googleusercontent.com/um...
# 95         City One  <img src="https://lh3.googleusercontent.com/um...
# 96      Sha Tin Wai  <img src="https://lh3.googleusercontent.com/um...
# 97  Che Kung Temple  <img src="https://lh3.googleusercontent.com/um...
#
#      longitude   latitude  altitude
# 0   113.942304  22.321828       0.0
# 1   113.936548  22.315947       0.0
# 2   114.107459  22.358321       0.0
# 3   114.161500  22.304701       0.0
# 4   114.158179  22.284872       0.0
# ..         ...        ...       ...
# 93  114.222622  22.408241       0.0
# 94  114.208653  22.387887       0.0
# 95  114.203535  22.382956       0.0
# 96  114.194770  22.376944       0.0
# 97  114.186262  22.375049       0.0
#
# [98 rows x 5 columns]

# %%
df_zone = pd.read_csv("../data/processed/zones.csv")
df_zone
# Out:
#         name       lat1       lat2        lon1        lon2
# 0    001-001  22.188762  22.212864  113.839997  113.871762
# 1    001-002  22.188762  22.212864  113.871762  113.903527
# 2    001-003  22.188762  22.212864  113.903527  113.935292
# 3    001-004  22.188762  22.212864  113.935292  113.967057
# 4    001-005  22.188762  22.212864  113.967057  113.998822
# ..       ...        ...        ...         ...         ...
# 220  015-011  22.526193  22.550295  114.157646  114.189411
# 221  015-012  22.526193  22.550295  114.189411  114.221176
# 222  015-013  22.526193  22.550295  114.221176  114.252941
# 223  015-014  22.526193  22.550295  114.252941  114.284706
# 224  015-015  22.526193  22.550295  114.284706  114.316471
#
# [225 rows x 5 columns]

# %%
df_district = pd.read_csv("../data/processed/districtAll.csv")
df_district
# Out:
#                         district  latitude  longitude     Total  \
# 0   Central and Western District  22.28219  114.14486   87700.0
# 1                        Eastern  22.27722  114.22519  188400.0
# 2               Islands District  22.26382  113.96038   67400.0
# 3          Kowloon City District  22.32866  114.19121  146500.0
# 4                     Kwai Tsing  22.35288  114.10004  176600.0
# 5                      Kwon Tong  22.31326  114.22581  247400.0
# 6                          North  22.49471  114.13812  111300.0
# 7                  Sai Kung Area  22.38198  114.27017  166900.0
# 8                        Sha Tin  22.38715  114.19534  245800.0
# 9                   Sham Shui Po  22.32989  114.16250  164700.0
# 10                      Southern  22.25801  114.15308   86200.0
# 11               Tai Po District  22.43995  114.16540  110500.0
# 12            Tsuen Wan District  22.37908  114.10598  114100.0
# 13                      Tuen Mun  22.39161  113.96792  187200.0
# 14                      Wan Chai  22.27702  114.17232   63200.0
# 15                  Wong Tai Sin  22.34299  114.19302  147200.0
# 16                 Yau Tsim Mong  22.32105  114.17261  123600.0
# 17            Yuen Long District  22.41667  114.05000  234700.0
#
#     Average household sie  Median income
# 0                     2.6        42000.0
# 1                     2.8        31500.0
# 2                     2.7        28800.0
# 3                     2.7        29700.0
# 4                     2.7        23300.0
# 5                     2.7        22200.0
# 6                     2.7        23300.0
# 7                     2.9        37200.0
# 8                     2.8        27100.0
# 9                     2.6        22000.0
# 10                    2.9        33000.0
# 11                    2.8        30000.0
# 12                    2.8        31800.0
# 13                    2.6        25400.0
# 14                    2.6        40400.0
# 15                    2.7        23300.0
# 16                    2.5        27900.0
# 17                    2.8        27000.0

# %%
import pandas as pd

# assume df_zone is a dataframe with columns lat1, lat2, lon1, lon2 that define your zones
# assume df_wellcome is a dataframe with columns latitude and longitude that define the locations of the shops

# create an empty list to store the number of shops in each zone
num_shops = []
rating_list = []
num_rating_list = []

# loop through each zone in df_zone
for i in range(len(df_zone)):
    # extract the boundaries of the current zone
    lat1, lat2, lon1, lon2 = df_zone.iloc[i][["lat1", "lat2", "lon1", "lon2"]]

    # count the number of shops in the current zone by checking if their latitude and longitude are within the zone boundaries
    num_shops_in_zone = (
        (df_wellcome["latitude"] >= lat1)
        & (df_wellcome["latitude"] <= lat2)
        & (df_wellcome["longitude"] >= lon1)
        & (df_wellcome["longitude"] <= lon2)
    ).sum()

    rating = df_wellcome[
        (df_wellcome["latitude"] >= lat1)
        & (df_wellcome["latitude"] <= lat2)
        & (df_wellcome["longitude"] >= lon1)
        & (df_wellcome["longitude"] <= lon2)
    ]["rating"].mean()

    rating_total = df_wellcome[
        (df_wellcome["latitude"] >= lat1)
        & (df_wellcome["latitude"] <= lat2)
        & (df_wellcome["longitude"] >= lon1)
        & (df_wellcome["longitude"] <= lon2)
    ]["user_ratings_total"].mean()

    # append the number of shops in the current zone to the list
    num_shops.append(num_shops_in_zone)
    rating_list.append(rating)
    num_rating_list.append(rating_total)



# add the num_shops list as a new column to df_zone
df_zone["Number_of_shop"] = num_shops
df_zone["ratingMean"] = rating_list
df_zone['Number_of_rating_Mean'] = num_rating_list

# %% [markdown]
# # busStop

# %%
def get_num_of_target_place(df_zone,df_target):
    num = []
    for i in range(len(df_zone)):
        lat1, lat2, lon1, lon2 = df_zone.iloc[i][['lat1', 'lat2', 'lon1', 'lon2']]
        num_busStop_in_zone = ((df_target['latitude'] >= lat1) & (df_target['latitude'] <= lat2) & (df_target['longitude'] >= lon1) & (df_target['longitude'] <= lon2)).sum()
        num.append(num_busStop_in_zone)
    return num

# %%
df_zone['Number_of_busStop'] = get_num_of_target_place(df_zone,df_busStop)

# %% [markdown]
# # Mtr Station

# %%
df_zone['Number_of_Mtr'] = get_num_of_target_place(df_zone,df_mtr)
df_zone
# Out:
#         name       lat1       lat2        lon1        lon2  Number_of_shop  \
# 0    001-001  22.188762  22.212864  113.839997  113.871762               0
# 1    001-002  22.188762  22.212864  113.871762  113.903527               0
# 2    001-003  22.188762  22.212864  113.903527  113.935292               0
# 3    001-004  22.188762  22.212864  113.935292  113.967057               0
# 4    001-005  22.188762  22.212864  113.967057  113.998822               0
# ..       ...        ...        ...         ...         ...             ...
# 220  015-011  22.526193  22.550295  114.157646  114.189411               0
# 221  015-012  22.526193  22.550295  114.189411  114.221176               0
# 222  015-013  22.526193  22.550295  114.221176  114.252941               0
# 223  015-014  22.526193  22.550295  114.252941  114.284706               0
# 224  015-015  22.526193  22.550295  114.284706  114.316471               0
#
#      ratingMean  Number_of_rating_Mean  Number_of_busStop  Number_of_Mtr
# 0           NaN                    NaN                  0              0
# 1           NaN                    NaN                  0              0
# 2           NaN                    NaN                  0              0
# 3           NaN                    NaN                  0              0
# 4           NaN                    NaN                  0              0
# ..          ...                    ...                ...            ...
# 220         NaN                    NaN                  2              0
# 221         NaN                    NaN                 20              0
# 222         NaN                    NaN                  1              0
# 223         NaN                    NaN                  0              0
# 224         NaN                    NaN                  0              0
#
# [225 rows x 10 columns]

# %% [markdown]
# # Competitor

# %%
df_competitor = pd.read_csv("../data/processed/competitor.csv")
df_competitor
# Out:
#                                    name  \
# 0                  express by PARKnSHOP
# 1        Wellcome - Yat Tung Superstore
# 2                          Market Place
# 3                              Wellcome
# 4                  Wellcome Supermarket
# ..                                  ...
# 295                            Wellcome
# 296                 Hui Jun Supermarket
# 297                            Wellcome
# 298             Kai Bo Food Supermarket
# 299  PARKnSHOP Click & Collect (荃灣麗城花園)
#
#                                      formatted_address  \
# 0    Chek Lap Kok, Scenic Rd, 8號地面上層H-I室 Units H & ...
# 1    Shop No 110, 1/F Eaton Shopping Centre, Yat Tu...
# 2                                           Tung Chung
# 3                             Ying Tung Rd, Tung Chung
# 4    Government Offices, Mui Wo, 2 Ngan Kwong Wan R...
# ..                                                 ...
# 295  Tai Hang Tung Estate Tung Lung House, Shop 4-1...
# 296                       295 Tai Nan St, Sham Shui Po
# 297                                          Kwai Fong
# 298  Mei Foo Sun Chuen, Broadway, 1-12,14-25,27,29號...
# 299  麗城花園三期麗城薈街市M22至M69 Shop M22-M69, G/F, Belveder...
#
#                         place_id  rating  user_ratings_total  \
# 0    ChIJBWcewr7iAzQRtFniX2gwnjI     4.9                   8
# 1    ChIJibJ9J6HiAzQR6f60A8w4neE     3.6                 214
# 2    ChIJc_HM8LTiAzQR2y2gEnZ7rec     4.1                  85
# 3    ChIJY0vZg8_jAzQRdi4RNFDW0Io     3.8                  31
# 4    ChIJeQk2SitWATQRkLuiM6FNDSM     3.9                 140
# ..                           ...     ...                 ...
# 295  ChIJwfkC2jQHBDQRuGoPng9c9q0     3.4                  92
# 296  ChIJ8ZbxkbMABDQRzJCSfl9aPUo     0.0                   0
# 297  ChIJ_45mDr34AzQRk9f_hNTPCCU     3.5                 186
# 298  ChIJw_1_NTP_AzQRkGSGrwTcPqs     3.3                  87
# 299  ChIJT2oQ87D5AzQRJWVkE9CKRW8     3.6                 181
#
#                                                  types   latitude   longitude
# 0    ['supermarket', 'grocery_or_supermarket', 'sto...  22.298215  113.934145
# 1    ['supermarket', 'grocery_or_supermarket', 'sto...  22.281394  113.934796
# 2    ['supermarket', 'grocery_or_supermarket', 'sto...  22.294966  113.951054
# 3    ['supermarket', 'grocery_or_supermarket', 'sto...  22.296000  113.953457
# 4    ['supermarket', 'grocery_or_supermarket', 'sto...  22.264011  114.001509
# ..                                                 ...        ...         ...
# 295  ['supermarket', 'grocery_or_supermarket', 'sto...  22.331574  114.171169
# 296  ['supermarket', 'grocery_or_supermarket', 'sto...  22.328866  114.160961
# 297  ['supermarket', 'grocery_or_supermarket', 'sto...  22.358124  114.129816
# 298  ['supermarket', 'grocery_or_supermarket', 'sto...  22.336754  114.137739
# 299  ['supermarket', 'grocery_or_supermarket', 'sto...  22.371530  114.101659
#
# [300 rows x 8 columns]

# %%
df_zone['Number_of_competitor'] = get_num_of_target_place(df_zone,df_competitor)

# %% [markdown]
# # District

# %%
for i, zone in df_zone.iterrows():
    for j, district in df_district.iterrows():
        if (zone['lat1'] <= district['latitude'] <= zone['lat2']) and (zone['lon1'] <= district['longitude'] <= zone['lon2']):
            df_zone.at[i, 'district'] = district['district']
            break

# %%
df_zone
# Out:
#         name       lat1       lat2        lon1        lon2  Number_of_shop  \
# 0    001-001  22.188762  22.212864  113.839997  113.871762               0
# 1    001-002  22.188762  22.212864  113.871762  113.903527               0
# 2    001-003  22.188762  22.212864  113.903527  113.935292               0
# 3    001-004  22.188762  22.212864  113.935292  113.967057               0
# 4    001-005  22.188762  22.212864  113.967057  113.998822               0
# ..       ...        ...        ...         ...         ...             ...
# 220  015-011  22.526193  22.550295  114.157646  114.189411               0
# 221  015-012  22.526193  22.550295  114.189411  114.221176               0
# 222  015-013  22.526193  22.550295  114.221176  114.252941               0
# 223  015-014  22.526193  22.550295  114.252941  114.284706               0
# 224  015-015  22.526193  22.550295  114.284706  114.316471               0
#
#      ratingMean  Number_of_rating_Mean  Number_of_busStop  Number_of_Mtr  \
# 0           NaN                    NaN                  0              0
# 1           NaN                    NaN                  0              0
# 2           NaN                    NaN                  0              0
# 3           NaN                    NaN                  0              0
# 4           NaN                    NaN                  0              0
# ..          ...                    ...                ...            ...
# 220         NaN                    NaN                  2              0
# 221         NaN                    NaN                 20              0
# 222         NaN                    NaN                  1              0
# 223         NaN                    NaN                  0              0
# 224         NaN                    NaN                  0              0
#
#      Number_of_competitor district
# 0                       0      NaN
# 1                       0      NaN
# 2                       0      NaN
# 3                       0      NaN
# 4                       0      NaN
# ..                    ...      ...
# 220                     0      NaN
# 221                     0      NaN
# 222                     0      NaN
# 223                     0      NaN
# 224                     0      NaN
#
# [225 rows x 12 columns]

# %%
df_zone.describe()
# Out:
#              lat1        lat2        lon1        lon2  Number_of_shop  \
# count  225.000000  225.000000  225.000000  225.000000      225.000000
# mean    22.357477   22.381580  114.062352  114.094116        0.546667
# std      0.104366    0.104366    0.137546    0.137546        2.287154
# min     22.188762   22.212864  113.839997  113.871762        0.000000
# 25%     22.261069   22.285171  113.935292  113.967057        0.000000
# 50%     22.357477   22.381580  114.062352  114.094116        0.000000
# 75%     22.453886   22.477988  114.189411  114.221176        0.000000
# max     22.526193   22.550295  114.284706  114.316471       25.000000
#
#        ratingMean  Number_of_rating_Mean  Number_of_busStop  Number_of_Mtr  \
# count   27.000000              27.000000         225.000000     225.000000
# mean     3.622627             129.875452          19.168889       0.435556
# std      0.221766              83.937469          38.767253       1.338502
# min      3.177778               4.000000           0.000000       0.000000
# 25%      3.500000              67.500000           0.000000       0.000000
# 50%      3.600000             121.800000           2.000000       0.000000
# 75%      3.757500             175.500000          21.000000       0.000000
# max      4.100000             420.000000         332.000000      10.000000
#
#        Number_of_competitor
# count            225.000000
# mean               1.333333
# std                3.821929
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%                0.000000
# max               29.000000

# %%
df_zone.to_csv("../data/processed/zoneAnalysis.csv", index=False)
